# %%
# Importing modeules that are required
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import BayesianRidge, LinearRegression
  
# Loading dataset
dataset = load_boston()
X, y = dataset.data, dataset.target
  
# Splitting dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 42)
  
# Creating and training model
model = BayesianRidge()
model.fit(X_train, y_train)
  
# Model making a prediction on test data
prediction = model.predict(X_test)
  
# Evaluation of r2 score of the model against the test set
print(f"R2 Score of Test Set : {r2_score(y_test, prediction)}")
# Out:
# R2 Score of Test Set : 0.7943355984883816

# %%
# Creating and training model for Linear Regression
model1 = LinearRegression()
model1.fit(X_train, y_train)
  
# Model making a prediction on test data
prediction1 = model1.predict(X_test)
  
# Evaluation of r2 score of the model against the test set
print(f"R2 Score of Test Set : {r2_score(y_test, prediction1)}")
# Out:
# R2 Score of Test Set : 0.7899225946923952

# %% [markdown]
# Using GridSearchCV to identify best models

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
parameters = {'alpha':[0.5, 1]}
lasso = Lasso()
lasso = GridSearchCV(lasso, parameters)
lasso.fit(X_train, y_train)
pred=lasso.predict(X_test)
print("Best Estimator for Lasso Model:\n",lasso.best_estimator_)
print("Best Score for Lasso Model:\n", lasso.best_score_)
# Out:
# Best Estimator for Lasso Model:
#  Lasso(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
# Best Score for Lasso Model:
#  0.680781277869548

# %%
ridge = Ridge()
ridge = GridSearchCV(ridge, parameters)
ridge.fit(X_train, y_train)
pred=ridge.predict(X_test)
print("Best Estimator for Ridge Model:\n",ridge.best_estimator_)
print("Best Score for Ridge Model:\n", ridge.best_score_)
# Out:
# Best Estimator for Ridge Model:
#  Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)
# Best Score for Ridge Model:
#  0.7049770812169888

# %% [markdown]
# You can import a series of libraries with a couple of lines using pyforest

# %%
# !pip install pyforest
# Out:
# Collecting pyforest
#   Downloading pyforest-1.1.0.tar.gz (15 kB)
# Building wheels for collected packages: pyforest
#   Building wheel for pyforest (setup.py) ... done
#   Created wheel for pyforest: filename=pyforest-1.1.0-py2.py3-none-any.whl size=14607 sha256=ae76912d6b7d3e121b2161d763af02bf5749deed321f808d79ea6b24fee72639
#   Stored in directory: /root/.cache/pip/wheels/61/1c/da/48e6c884142d485475d852d69d20a096aba5beceb338822893
# Successfully built pyforest
# Installing collected packages: pyforest
# Successfully installed pyforest-1.1.0

# %%
from pyforest import *

# %%
lazy_imports()
# Out:
# ['from sklearn import metrics',
#  'from xlrd import open_workbook',
#  'import pandas as pd',
#  'from sklearn.ensemble import RandomForestRegressor',
#  'from scipy import stats',
#  'import statistics',
#  'import awswrangler as wr',
#  'import bokeh',
#  'from sklearn.linear_model import RidgeCV',
#  'import os',
#  'import fastai',
#  'import pickle',
#  'import tqdm',
#  'import gensim',
#  'from sklearn.ensemble import GradientBoostingRegressor',
#  'from sklearn.linear_model import Ridge',
#  'from fbprophet import Prophet',
#  'from statsmodels.tsa.arima_model import ARIMA',
#  'import cv2',
#  'from sklearn.model_selection import RandomizedSearchCV',
#  'from sklearn.ensemble import GradientBoostingClassifier',
#  'from sklearn.model_selection import cross_val_score',
#  'from sklearn.linear_model import LogisticRegression',
#  'import altair as alt',
#  'import dash',
#  'import lightgbm as lgb',
#  'import sys',
#  'import plotly.express as px',
#  'from sklearn.linear_model import LassoCV',
#  'from dask import dataframe as dd',
#  'from sklearn.linear_model import Lasso',
#  'import statsmodels.api as sm',
#  'import skimage',
#  'from sklearn.linear_model import LinearRegression',
#  'from sklearn.preprocessing import LabelEncoder',
#  'from sklearn.decomposition import PCA',
#  'from sklearn.preprocessing import MinMaxScaler',
#  'from sklearn.preprocessing import OneHotEncoder',
#  'from sklearn.linear_model import ElasticNet',
#  'from sklearn import svm',
#  'import nltk',
#  'from sklearn.linear_model import ElasticNetCV',
#  'import re',
#  'import pydot',
#  'import plotly.graph_objs as go',
#  'from sklearn.feature_extraction.text import TfidfVectorizer',
#  'import matplotlib.pyplot as plt',
#  'import tensorflow as tf',
#  'from scipy import signal as sg',
#  'import textblob',
#  'import matplotlib as mpl',
#  'import xgboost as xgb',
#  'from openpyxl import load_workbook',
#  'import plotly as py',
#  'from sklearn.model_selection import KFold',
#  'from sklearn.preprocessing import StandardScaler',
#  'from sklearn.preprocessing import RobustScaler',
#  'from sklearn.feature_extraction.text import CountVectorizer',
#  'import keras',
#  'from sklearn.preprocessing import PolynomialFeatures',
#  'from sklearn.cluster import KMeans',
#  'import sklearn',
#  'import glob',
#  'import fbprophet',
#  'from PIL import Image',
#  'import spacy',
#  'from sklearn.manifold import TSNE',
#  'from pathlib import Path',
#  'from sklearn.model_selection import StratifiedKFold',
#  'import torch',
#  'from pyspark import SparkContext',
#  'import datetime as dt',
#  'import seaborn as sns',
#  'import numpy as np',
#  'from sklearn.model_selection import GridSearchCV',
#  'from sklearn.model_selection import train_test_split',
#  'import imutils',
#  'from sklearn.impute import SimpleImputer',
#  'from sklearn.ensemble import RandomForestClassifier']
